# %% [markdown]
# # DATASCI S11 Final Project CBMS Dataset
# ### By : Amiel James Bornales, Jonn Ralge Yuvallos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium
# %matplotlib inline

# %% [markdown]
# doot noot
#
#
# locs: Indicates brgy within
# we need brgy loc

# %% [markdown]
# ### For faster loading of the dataframe

# %%
df_cols = ['mainid', 'hpq_memid', 'memno', 'nucfam', 'reln', 'reln_o', 'sex',
       'birth_date', 'age', 'age_yr', 'birth_reg', 'civstat', 'ethgrp',
       'ethgrp_o', 'ofw', 'mlenresid', 'country_resid', 'country_resid_o',
       'prov_resid_code', 'mun_resid_code', 'brgy_resid_code', 'mun_resid_txt',
       'brgy_resid_txt', 'educind', 'gradel', 'sch_type', 'gradel_calc',
       'ynotsch', 'ynotsch_o', 'educal', 'psced7', 'course_o', 'literind',
       'regvotind', 'voted_last_election', 'jobind', 'entrepind', 'njob',
       'occup', 'psoc4', 'indust', 'psic4', 'jstatus', 'work_ddhrs',
       'work_wkhrs', 'fadd_work_hrs', 'fxtra_wrk', 'workcl', 'fjob',
       'first_fjob', 'jsearch_meth', 'jsearch_meth_o', 'wks_fjob',
       'ynotlookjob', 'ynotlookjob_o', 'lastlookjob', 'joppind', 'wtwind',
       'wagcshm', 'wagkndm', 'sss_ind', 'pregind', 'solo_parent', 'pwd_ind',
       'pwd_type', 'pwd_type_o', 'pwd_id', 'scid_ind', 'mcrimeind',
       'mtheftind', 'mrapeind', 'minjurind', 'mcarnapind', 'mcattrustlind',
       'mocrimind', 'mocrim', 'mtheftloc', 'mrapeloc', 'minjurloc',
       'mcarnaploc', 'mcattrustlloc', 'mocrimloc', 'mnutind', 'mnutind_date']
d_type = ['object','float64','int64','float64','object','float64','int64','float64',
          'int64','float64','float64','float64','float64','object','object','int64',
          'float64','float64','object','int64','object','float64','float64','object',
          'float64','float64','float64','float64','float64','object','float64','float64',
          'float64','object','float64','object','float64','object','float64','float64',
          'float64','float64','float64','object','float64','int64','object','float64',
          'float64','float64','float64','float64','object','float64','object','float64',
          'float64','int64','float64','float64','float64','float64','float64','float64',
          'float64','object','float64','object','object','float64','float64','object',
          'float64','int64','float64','int64','object','float64','float64','object',
          'int64','float64','float64','float64']
dtypes = dict(zip(df_cols, d_type))

# %%
df = pd.read_csv('data/hpq_mem.csv', dtype = dtypes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-5086f55d73ba> in <module>
# ----> 1 df = pd.read_csv('data/hpq_mem.csv', dtype = dtypes)
#
# D:\Program Files\Python\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# D:\Program Files\Python\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# D:\Program Files\Python\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# D:\Program Files\Python\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# D:\Program Files\Python\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# D:\Program Files\Python\lib\site-packages\pandas\core\dtypes\common.py in pandas_dtype(dtype)
#    2011
#    2012     try:
# -> 2013         npdtype = np.dtype(dtype)
#    2014     except (TypeError, ValueError):
#    2015         raise
#
# TypeError: data type "mcarnaploc" not understood

# %%
df['brgy_resid_txt'].unique()
# Out:
# array([nan, 'Sta Cruz', 'barangka', 'Sta Mesa', 'oriental', '1',
#        'maypajo', 'pimentel', 'dariwdiw', 'san pascual', 'macario',
#        'sibalo', 'bangkal st.', 'hindi alam', '121', 'san isidro',
#        'Tabing bakod', 'bagong tubig', 'concepcion', 'baclaran',
#        'san jose', 'bagumbayan', 'BALAYANG', 'balayang', 'alegria',
#        'bangkal', 'barangay 843', 'barangay 844', 'barangay 842',
#        'barangay 10', 'burol', 'bacoor', 'baesa', 'tilod', 'barangay 2',
#        'brangay 2', 'lipa', 'lip', 'casim', 'Brgy.157, Malibay',
#        'Rosario', 'Libertad', 'Vito Cruz', 'san nicolas', 'poblacion',
#        '155', 'none', 'san andres', 'yocti', 'malibay', 'palta Big',
#        'san rafael buhi', 'tarlac', 'la paz', 'paco', 'bagong sikat',
#        'pag-asa', 'brgy tikay', 'brgy salitran', 'nueva victoria',
#        'balibago', 'dapitan', 'balagtas', 'brgy 1 (pob)',
#        'barangay 1(pob)', 'kamuning', 'talahid', 'barangay 21',
#        'san miguel', 'san juan', 'don ramon', 'bagongbong', 'arguelles',
#        'del pilar', 'daraga', 'burgos', 'sta ana', 'San Vicente',
#        '442 rizal ave', 'barangay 13', 'santan st kalawaan', 'apas cebu',
#        'e cornejo', 'sta barbara', 'sivilla', 'dalumpinas', 'bulualto',
#        'molave', 'balingasa', 'camantigue st maricaban', 'barangay 179',
#        'matapat st', 'malibay E rodriguez st', 'E rodriguez malibay',
#        '166', 'Baclaran', '137', '159', 'Brgy 159', '175', '171',
#        'Paliparan', 'Palar', '162', 'Guadalupe', '163', 'Nabua', '-',
#        'Talaba', 'damayanlagi', '135', 'nabua', 'Sta.Maria', '161',
#        'barangay 161', 'Barangay 161', 'fti', 'pandacan', 'carmona',
#        'pili', 'aurora', 'san carlos', 'Gogon', 'Golden city', '174',
#        'tignoan', '169', 'st. frances', '177', 'dodan', 'pagalunan',
#        'santoñio', 'libis', '172 Geronimo st.', 'b', 'Brgy 173', '173',
#        '76', 'tabi gubat', '139', '168 santa cruz manila', 'roxas city',
#        '176', 'camarines sur', 'sigma', 'malibay 174', 'pulang lupa',
#        'san marino', 'dauin', '335 zone 31', 'brgy tambo', '53 tramo',
#        '53', 'brgy legarda sampaloc',
#        'interion 10 bernavides street.sta cruz',
#        'interion10,bernavides street,sta cruz', 'San Fernando Norte',
#        '114/Dimasalang', '114 / Dimasalang', '98', 'rosario', 'fairview',
#        'Inupacan', 'Escalante', 'San Rafael', 'Aborlan',
#        'St.Teresa, Maricaban', 'Anabu II', 'Triumph,Zone 1',
#        'alponso tolentino', '122', 'barangay 122', '135 vizcarra',
#        'tandangsora', 'kabankalan', 'usab', '134', '134 magtibay',
#        'tramo', 'tayuman', 'Tayuman', '165', '158', '748', 'barangay 163',
#        'Pinagkaisahan', 'Pinag kaisahan', 'Agpipili', 'Brgy 163',
#        'Balbagin', 'balbagin', 'brgy 169 viscarra', 'brgy 169 viscara',
#        'brgy 169 . viscara st', '169 viscara', 'tandang sora',
#        'kaytitinga 1 alfonzo', 'nordern publacion', '178',
#        'tenejeros/sanchez st.', 'brgy commonwealth', 'commonwealth',
#        'libis baesa', 'Barangka Drive Boni', '172', '181', '143',
#        'San antonio', 'Sitio', 'gogon', 'pembo', 'wester bicutan',
#        'Sta. Ana', '546', 'Barangay 1', 'Barangay Talisay',
#        'Barangay Tumana', 'San Jose', 'san Jose', 'Linao', '190',
#        'Sto. Nino, Brgy. 145', 'Barangay 190, Don Carlos Village',
#        'Don Carlos Village, Brgy. 190', 'Barangay 187', 'Barangay 190',
#        'don galo', 'San vicente', 'Cubao', 'Pembo', 'Bagong silang',
#        'Bagong Silang', 'Balod', 'pagkakaisa', 'Maroqillo', 'Manuyo 1',
#        'San Antonio', 'Barangay 166 C.Jose', 'Barangay Signal',
#        'Rizal pembo', 'palanan', 'ginsanghay', 'naga naga',
#        'san aurelio 3rd', '26', 'quezon city', 'san dionisio', '79',
#        '187', 'nakalimutan na', 'malalag street', '131', '188', 'Mexico',
#        'Sto. nino, brgy. 145', '145', 'Sto. Nino St., Brgy. 145',
#        'bicutan', 'Alicia', 'Bocandala', 'Talundos', 'Conteberda',
#        'Barangay Canabay', 'Udtol', 'Budtol', 'Bolinao', 'Kusina',
#        'Villa', '196', 'Pildera', 'sucat', 'Tandang Sora', 'Barangay 183',
#        '128', 'pasaytaft', 'Canbagdroy', 'Bagong Barrio', 'Juban', 'MCU',
#        'Brgy. Sto. Domingo', 'San Roque', 'n8ne', '11', '186', 'Delpan',
#        'Alabang', 'cubao', 'Malate', 'Barangay 75', 'Barangay 92',
#        'malate', 'Barangay 89', 'Barangay MBVS', 'Tamayo', 'Balite',
#        'La Carlota', 'Sto Niño', 'Cibulano', 'tambo', 'Sum-ag',
#        'Barangay 80', 'Barangay 91', 'salvacion', 'Signal', '201', '0',
#        '999', 'San roque', 'Calabacita', 'malitbugay', 'Don bosco',
#        'Santa Rita', 'salitran', 'Baloling', 'Bago', 'Hanahawan', '142',
#        'San miguel', 'San Miguel', 'falmarez st,', 'Mandalagan', 'sigcay',
#        'sinarawan', 'quiling', 'evangelista', 'looc', 'mayamot',
#        'plainview', 'almanza 2', 'brgy sta.cruz', 'brgy sto.niño',
#        'brgy valenzuela rizal village', 'brgy peña',
#        'tolentino st malibay', 'brgy isbacbac', 'brgy paras',
#        'Barangay Baldios', '58', 'road1', 'Road 1', '72', '120',
#        'Brgy. 184', 'moonwalk', 'Labo', 'inuncan', 'villamor',
#        'libis baisa', 'villa merzedez', 'Turak', 'turak', 'limay', '157',
#        'sanjuan', 'binalay', 'casiligan', 'silang', 'parada gubat',
#        'botocan', 'babag 2', 'purok13 daang hari', 'dela paz',
#        'p.villanueva', 'east rembo', '179', '180', 'tengco', 'sua', 'pb1',
#        'bagong buhay', 'bocana', 'banaybanay', 'kay pian',
#        'silangan malicboy', 'apelo extension', 'oda', 'bitas', '197',
#        '168', 'quinagabian', 'Brgy Fairview', 'Brgy fairview', 'Bangkal',
#        '184', 'Brgy Tondo', 'Macanaya', 'Barangay Pateros',
#        'Western Bicutan', 'Maragondon', 'Banlat', 'Barangay Silverio',
#        'taft', 'ermita', 'Baltao Rd. Barangay 197', 'quiapo', 'tabina',
#        'port area', 'Sagkahan', 'Abango', '208', 'barangay 166',
#        'Don galo', '12', 'Manuyo 2', '45', 'brgy. 58', 'Tambo',
#        'Garita A', '-----', 'Balik-balik', 'Pagsanghan', 'Lugam', '---',
#        'Morayta', 'sa isidro', 'sta elena', 'pangpang', 'sto nino',
#        'libertad', 'Kidawis', '109', 'D. Reyes st.', 'salawag', 'brgy27',
#        'brgy39', 'talaba', 'Tondo', 'san roque', 'tondo', 'san luis',
#        'Sta Monica', 'venanilla st', 'ventanilla st', 'orenbo', 'x',
#        'm dela cruz', 'Palanan', 'Santa Fe', 'Maayon', 'Calbayog',
#        'Lower Bicutan', 'Lower bicutan', 'Barangay Bangkal', 'kawayan',
#        'brgy gomez', 'Arpapa D-Gomez, Baryo Obrero', 'P-Del Rosario',
#        'Calit-calit', 'Mangoso', '191', '70', 'Floodway', '1618 Zone 16',
#        '464 Zone 46', '99', 'East Rembo', 'Kastila Sitte', 'San Isidro',
#        '.', 'Upper Bicutan', 'Brgy San Isidro', 'Dimaculangan',
#        '117 Hembrador', '117Hembrador', 'Fb Harrison', '113 Vergel',
#        'Makati', 'Manila', 'Dimapait', 'Bued Calasaio', 'Consolacion',
#        'Samar', 'Tuburan', 'Catagbacan', 'Langgam', 'Dimapulaan',
#        'Bued Calasiao', 'Iba', 'Malagauos', 'San Benito', 'Polo',
#        'Laoag City', 'Tagum', 'Roxas', 'Pangadian', 'Kalabo', 'Iligan',
#        'Villa Nuñez', 'Times Spirig', 'Timog', 'Laoag', 'Palo Palo',
#        'Tenement', 'Dimapula', 'Pulang Bato', 'Malagansa', 'Ligas',
#        'San Juaquin', 'San Jaquin', 'Dimakulangan', 'dimakulangan',
#        'dimakulangn', 'San Fernando', 'San Pablo', 'Laram',
#        'Pnr tenement', 'Giguinto', 'Couangco', 'Jolo', 'Antongayon',
#        'Rizal', 'Mambog 3', 'Mapayan', 'Ugong', 'Project 4',
#        'western bicutan', 'Luciana', 'Carbat', 'Tampo', 'Look', 'Galang',
#        'Kamagong', 'Baybay', 'Sariaya', '160', 'san juanico',
#        'san antonio', 'area D', 'Payatas', 'Nothern Catarman',
#        'nothern Catarman', '135 Osmena highways, Paco',
#        '1935 Osmmena Highways, Paco', 'San Dionisio',
#        'Barangay San Dionisio', 'Cantabaco', 'Malibay', 'Maricaban',
#        '140', '183', 'Leveriza', 'M.Dela Cruz', 'Gen.Trias',
#        'Trece Cavite', 'Silang Cavite', 'Bued Calisaio', 'Apalit',
#        '117 zone 14', 'Pitugo', 'barangay 26', 'Sagana',
#        'Camachili San Valley', 'Barangay Pio', 'Mamatid', 'Barangay 66',
#        'estrella', 'sta cruz', 'sta. cruz', 'potatan st', 'Baua Gonzaga',
#        'Centro', 'Dian Palanana', 'Cordura', 'brgy 77', 'bangka bangka',
#        'maipon', 'Pamplona', '194', '193', 'Alimunan', 'Peldera',
#        'Pinagsama', 'Peldira', 'Pio del Pilar', 'Pio Del Pilar',
#        'Olenfia', 'Kabayan', 'Almansa 2', 'Bilog Bilog', 'Binubusan',
#        'Perla', 'Ajong', 'Tabucan', 'olivares', 'Natatas', 'Washington',
#        'A Santos brgy. Tijeros', 'Park Lane Country Homes', 'Boni',
#        'Bangcal', '56', 'Mabato -bato', 'Centry Site', 'Mambugan', '127',
#        '358 Magallanes', '358 Magallanes st.', 'Maguyam', 'Mampirad',
#        'Mayanao', 'Mampirao', 'Bangao', 'Ayungan', 'M Dela Cruz',
#        'La Nieves', 'Blessed Vill', '200', 'San valley', 'San Valley',
#        'Peña Plata', 'Sto.Niño', 'Patag', 'Calumpang', '126', 'm reyes',
#        'Sun Valley', 'Brgy. Sto. Niño', 'Novaliches', 'Sibagay',
#        'Kabagan', 'Mabalacat', 'Cilay', 'Zapote,Pamplona 1', 'Toledo',
#        'san perdo', 'marcos', 'Zone 10 -A', 'Salong', 'Progreso',
#        'Mary Cris Complex', 'San Dionsio', 'Brgy. Poblacion',
#        'Brgy.Poblacion', 'Brgy.Gines Patag', 'Gatbuca', 'Barangay 310',
#        'Barangay Malaya', 'Barangay Alaklan', 'Ilog Malino',
#        'Barangay Toklong', 'Barangay Tatalon', 'Buhay Na Lupa', 'Tutoban',
#        'Kalentong', 'Quirino', '136', 'Alaminos', 'Salug', 'Nankilam',
#        'Brgy. Butucan project 8', 'Brgy. 197', 'amalabay',
#        'Barangay Kalagane', 'Barangay Kalangane', 'Longos,Zapote 5',
#        'Barangay Sta.Catalina', 'Barangay Dipotae', 'Kabihashan',
#        'Kabihasnan', 'Barangay Danpel', 'Barangay Sibagay',
#        'Barangay Moson', 'angadanan', 'samar', 'kambong',
#        'Barangay Delkato', 'Barangay Polug', '--', 'Frisco', 'Sto. Niño',
#        'Barangay Burabura', 'Tejero', 'Barangay Darnorte', 'Silverio',
#        'Hamorawon', 'Barangay Tabe', 'Southern', 'Pag asa',
#        'Barangay Almanza', 'Talaba ll', 'Barangay San Isidro',
#        'Barangay Sun Valley', 'unknown', 'west crame', 'daang bukid',
#        'Arrab', 'ususan', 'kadaklan', 'zamora', 'Ilaya', 'i will hills',
#        'calobaoan', 'pamplona', 'delos santos', 'floodway', 'taray',
#        'pacita', '124', 'Salawag', 'tungko', 'basud', 'palapag',
#        'manggahan', 'Rivera', 'rivera', '----', 'Ermita', 'Capipiza',
#        'Santa Monica', 'Mother Ignacia', 'Barangay 108', 'j luna', '___',
#        '__', 'Sikatuna', 'Arkong Bato', 'Umboy', 'Bagbag 2', 'novaliches',
#        'Santo Cristo', 'San Carlos', 'tolentino', 'J Luna', '94',
#        'alabang', 'sampaloc', 'Bolo', 'pulang bato', 'Matatalaib',
#        'Hagdang Bato', 'Guindag an', 'Vaseca', 'Silang', 'Vasela',
#        'Barangay Pamplona', 'Barangay Leveriza', 'Pablo',
#        'Barangay Bidea', 'Barangay Roxas', 'Cagbilwang',
#        'Barangay Sta.Lucia', 'purok 2', 'Barangay Pulang Bato', '185',
#        'Bidea', 'Maligaya', 'San Juan', '95'], dtype=object)
